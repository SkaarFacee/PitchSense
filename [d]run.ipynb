# %%
from ultralytics import YOLO

model_path="/home/aanil/Data/aanil/side/yolo/outputs/yolo26_s_keypoint/baseline_aug_resize/weights/best.pt"
model=YOLO(model_path)
model.val(data=str(yaml_path), split="train", name="train_eval")

# %%
results=model.predict(
    './data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm',
    save=True,
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /Users/adi/Skaarfacee/github/PitchSense/data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm: 736x1280 16 players, 5 goalkeepers, 174.9ms
# video 1/1 (frame 2/750) /Users/adi/Skaarfacee/github/PitchSense/data/test_data/FULL MATCH ｜ BETIS 3 vs 5 FC BARCELONA ｜ LALIGA 2025⧸26 MD15 🔵🔴 [93LPZJkCW2w].webm: 736x1280 15 players, 5 goalkeepers, 134.5ms
# ...
